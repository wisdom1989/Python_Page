# %% [markdown]
# #### **Titanic Solution**

# %%
# Import Library

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# Load data on python

# %%
df = pd.read_csv(r'C:\Users\DELL\Desktop\Raw_Datasets\Titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Print starting 10 rows and last 10 rows

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
# Shape of the data

# %%
df.shape
# Out:
# (891, 12)

# %%
# Print all column name

# %%
df.columns.tolist()
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
# Find the data type of all the columns

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# Print information and summary

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# Count Survived and show on pie chart

# %%
df1 = df.Survived.value_counts()
df1
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
plt.pie(df1, autopct = '%0.1f%%', labels = ['Not-Survived', 'Survived'], colors = ['r', 'g'])
plt.title('Survived and Not-Survived Passengers')
plt.show()

# %%
# Find out how many female passengers had travelled in first class and show on pie chart

# %%
df.Sex.value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df_female = df[df.Sex == 'female']

# %%
df2 = df_female.Pclass.value_counts()
df2
# Out:
# Pclass
# 3    144
# 1     94
# 2     76
# Name: count, dtype: int64

# %%
plt.pie(df2, colors = ['#ef7f70', '#0a70bb', '#bb0a3a'], labels = ['Third class', 'First class', 'Second class'], autopct = '%0.01f%%',
        explode =(0,0.1,0))
plt.title('Female Passengers Travelled in Different Classes')
plt.show()

# %%
# Find out how many female passengers had Survived and her age <30, show on pie chart

# %%
#df_female[df_female.Age < 30]
df_female_age = df[(df.Age < 30) & (df.Sex == 'female')]
df3 = df_female_age.Survived.value_counts()
df3
# Out:
# Survived
# 1    105
# 0     42
# Name: count, dtype: int64

# %%
plt.pie(df3, colors = ['g', 'r'], labels = ['Survived', 'Not-survived'], autopct = '%0.2f%%', explode = (0.1,0))
plt.title('Female survivors of age < 30')
plt.show()

# %%
# Find out how many male passengers had Survived and his age >40, show on pie chart

# %%
df4 = df[(df.Sex == 'male') & (df.Age > 40)].Survived.value_counts()
df4
# Out:
# Survived
# 0    84
# 1    18
# Name: count, dtype: int64

# %%
plt.pie(df4, colors = ['r', 'g'], labels = ['Not-survived', 'Survived'], autopct = '%0.01f%%', explode = (0,0.1))
plt.title('Survived male passengers of age > 40')
plt.show()

# %%
# Show age with 20 bins

# %%
df.Age.head()
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: Age, dtype: float64

# %%
counts, bins, _ = plt.hist(df.Age, bins=20, color="yellow", edgecolor="red", label = 'Age bins')
bin_centers = (bins[:-1] + bins[1:]) / 2
plt.plot(bin_centers, counts, marker ='o', color = 'r', label = 'Age Distribution')

plt.xticks(np.arange(0, 84, 4))
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.legend ()
plt.show()

# %%
# Show age frequency with survived and not survived (Histogram)

# %%
df5 = df[df.Survived == 1].Age
df5.head()
# Out:
# 1    38.0
# 2    26.0
# 3    35.0
# 8    27.0
# 9    14.0
# Name: Age, dtype: float64

# %%
df5 = df[df.Survived == 1].Age

counts, bins, _ = plt.hist(df5, bins=20, color="yellow", edgecolor="red", label = 'Age bins')
bin_centers = (bins[:-1] + bins[1:]) / 2
plt.plot(bin_centers, counts, marker ='o', color = 'r', label = 'Age Distribution')

plt.xticks(np.arange(0, 84, 4))
plt.title("Survived Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.legend ()
plt.show()

# %%
df5 = df[df.Survived == 0].Age

counts, bins, _ = plt.hist(df5, bins=20, color="yellow", edgecolor="red", label = 'Age bins')
bin_centers = (bins[:-1] + bins[1:]) / 2
plt.plot(bin_centers, counts, marker ='o', color = 'r', label = 'Age Distribution')

plt.xticks(np.arange(0, 84, 4))
plt.title("Not-Survived Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.legend ()
plt.show()

# %%
# Show Bar graph for Survived with male, female, class

# %%
s_df = df[df.Survived == 1]

# %%
s_df.Sex.value_counts()
# Out:
# Sex
# female    233
# male      109
# Name: count, dtype: int64

# %%
s_df.Pclass.value_counts()
# Out:
# Pclass
# 1    136
# 3    119
# 2     87
# Name: count, dtype: int64

# %%
sns.countplot(x = 'Pclass', hue = 'Sex', data = s_df)
plt.show()

# %%
# How many passengers are travelled in different classes show in Bar graph

# %%
temp = df.Pclass.value_counts()
temp
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
value = list(temp)

# %%
data = dict(temp)
x = data.keys()
count = data.values()

# %%
count
# Out:
# dict_values([491, 216, 184])

# %%
val = []
for i in x:
    if i == 1:
        val.append("1st Class")
    elif i == 2:
        val.append("2nd Class")
    elif i == 3:
        val.append("3rd Class")

# %%
x
# Out:
# dict_keys([3, 1, 2])

# %%
val
# Out:
# ['3rd Class', '1st Class', '2nd Class']

# %%
plt.bar(val, count, color = ['red', 'green', 'blue'])
plt.title('Passenger Class')
plt.xlabel('Classes')
plt.ylabel('Count of passenger')
plt.show()

# %%
# How many passengers are survived with class wise and show in Bar graph

# %%
sns.countplot(x = "Pclass", hue = "Survived", data = df)
plt.show()

# %%
# Show Question-13 & Question-14 in subplot

# %%
fig, axs = plt.subplots(1,2, figsize = (10,3))
sns.countplot(x = 'Pclass', hue = 'Sex', data = s_df, ax = axs[0])
axs[0].set_title('Survived Passenger for Gender and Class')

axs[1].bar(val, count, color = ['red', 'green', 'blue'])
axs[1].set_title('Passenger Class')
axs[1].set_xlabel('Classes')
axs[1].set_ylabel('Count of passenger')

plt.show()

# %%
# Show Bar graph for Survived with 3rd class male, 1st class female

# %%
M3 = df[(df.Pclass == 3) & (df.Sex == 'male')].Survived.value_counts()
M3.plot(kind = 'bar', color = ['r', 'g'])
plt.title('3rd Class Male Passengers')
plt.show()

# %%
F1 = df[(df.Pclass == 1) & (df.Sex == 'female')].Survived.value_counts()
F1.plot(kind = 'bar', color = ['g', 'r'])
plt.title('1st Class Female Passengers')
plt.show()

# %%
fig, axs = plt.subplots(2,2, figsize = (10,8))
M3 = df[(df.Pclass == 3) & (df.Sex == 'male')].Survived.value_counts()
M3.plot(kind = 'bar', color = ['r', 'g'], ax = axs[0][0])
axs[0][0].set_title('3rd Class Male Passengers')

F1 = df[(df.Pclass == 1) & (df.Sex == 'female')].Survived.value_counts()
F1.plot(kind = 'bar', color = ['g', 'r'], ax = axs[0][1])
axs[0][1].set_title('1st Class Female Passengers')

sns.countplot(x = 'Pclass', hue = 'Sex', data = df[df.Survived == 1], ax = axs[1][0])
axs[1][0].set_title('Passenger Classes Along With Sex')

df4.plot(kind = 'pie', colors = ['r', 'g'], labels = ['Not-survived', 'Survived'], autopct = '%0.01f%%', explode = (0,0.1), ax = axs[1][1])
axs[1][1].set_title('Survived male passengers of age > 40')

plt.show()

# %%
# How many passengers are survived / not survived and they are 1st class female

# %%
df[(df.Pclass == 1) & (df.Sex == 'female')].Survived.value_counts()
# Out:
# Survived
# 1    91
# 0     3
# Name: count, dtype: int64

# %%
pd.crosstab(df['Pclass'], df['Sex'], margins = True)
# Out:
# Sex     female  male  All
# Pclass
# 1           94   122  216
# 2           76   108  184
# 3          144   347  491
# All        314   577  891

# %%
# Map the Sex column male=1, female =0

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.Sex = df.Sex.map({'male':1, 'female':0})

# %%
df.Sex.head(5)
# Out:
# 0    1
# 1    0
# 2    0
# 3    0
# 4    1
# Name: Sex, dtype: int64

# %%
# Find Null values

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Replace Null value to Median value

# %%
df.Age.isnull().sum()
# Out:
# 177

# %%
df[df.Age.isnull()].head(5)
# Out:
#     PassengerId  Survived  Pclass                           Name  Sex  Age  \
# 5             6         0       3               Moran, Mr. James    1  NaN
# 17           18         1       2   Williams, Mr. Charles Eugene    1  NaN
# 19           20         1       3        Masselmani, Mrs. Fatima    0  NaN
# 26           27         0       3        Emir, Mr. Farred Chehab    1  NaN
# 28           29         1       3  O'Dwyer, Miss. Ellen "Nellie"    0  NaN
#
#     SibSp  Parch  Ticket     Fare Cabin Embarked
# 5       0      0  330877   8.4583   NaN        Q
# 17      0      0  244373  13.0000   NaN        S
# 19      0      0    2649   7.2250   NaN        C
# 26      0      0    2631   7.2250   NaN        C
# 28      0      0  330959   7.8792   NaN        Q

# %%
df.Age.describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df['Age'] = df.Age.fillna(28)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
# Drop unwanted columns

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
cols = ['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked']

# %%
df[cols]
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    1  22.0      1      0   7.2500        S
# 1           1       1    0  38.0      1      0  71.2833        C
# 2           1       3    0  26.0      0      0   7.9250        S
# 3           1       1    0  35.0      1      0  53.1000        S
# 4           0       3    1  35.0      0      0   8.0500        S
# ..        ...     ...  ...   ...    ...    ...      ...      ...
# 886         0       2    1  27.0      0      0  13.0000        S
# 887         1       1    0  19.0      0      0  30.0000        S
# 888         0       3    0  28.0      1      2  23.4500        S
# 889         1       1    1  26.0      0      0  30.0000        C
# 890         0       3    1  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
final_df = df[cols]

# %%
final_df.loc[:, 'Sex'] = final_df.Sex.map({'male': 1, 'female': 0})

# %%
final_df.Sex = final_df.Sex.map({'male':1, 'female':0})
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9316\2964817611.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.Sex = final_df.Sex.map({'male':1, 'female':0})

# %%
final_df
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3  NaN  22.0      1      0   7.2500        S
# 1           1       1  NaN  38.0      1      0  71.2833        C
# 2           1       3  NaN  26.0      0      0   7.9250        S
# 3           1       1  NaN  35.0      1      0  53.1000        S
# 4           0       3  NaN  35.0      0      0   8.0500        S
# ..        ...     ...  ...   ...    ...    ...      ...      ...
# 886         0       2  NaN  27.0      0      0  13.0000        S
# 887         1       1  NaN  19.0      0      0  30.0000        S
# 888         0       3  NaN  28.0      1      2  23.4500        S
# 889         1       1  NaN  26.0      0      0  30.0000        C
# 890         0       3  NaN  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]
